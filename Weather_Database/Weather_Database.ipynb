# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of 2000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 777

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#test to make sure I'm indexing the weather description correctly
city_url = url + "&q=" + "London"
city_weather = requests.get(city_url).json()

city_description = city_weather["weather"][0]["description"]
#city_description
# Out:
# 'scattered clouds'

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        #city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Country": city_country,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})
                          #"Country": city_country,
                          #"Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | batsfjord
# Processing Record 2 of Set 1 | nome
# Processing Record 3 of Set 1 | flin flon
# Processing Record 4 of Set 1 | bluff
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | vao
# Processing Record 7 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 8 of Set 1 | faanui
# Processing Record 9 of Set 1 | manzhouli
# Processing Record 10 of Set 1 | barabinsk
# Processing Record 11 of Set 1 | sofiysk
# City not found. Skipping...
# Processing Record 12 of Set 1 | umm kaddadah
# Processing Record 13 of Set 1 | saint-francois
# Processing Record 14 of Set 1 | rikitea
# Processing Record 15 of Set 1 | bathsheba
# Processing Record 16 of Set 1 | ocote paulino
# Processing Record 17 of Set 1 | cabo san lucas
# Processing Record 18 of Set 1 | mandalgovi
# Processing Record 19 of Set 1 | hammerfest
# Processing Record 20 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 21 of Set 1 | college
# Processing Record 22 of Set 1 | ilulissat
# Processing Record 23 of Set 1 | ierapetra
# Processing Record 24 of Set 1 | saint george
# Processing Record 25 of Set 1 | san patricio
# Processing Record 26 of Set 1 | busselton
# Processing Record 27 of Set 1 | ola
# Processing Record 28 of Set 1 | yellowknife
# Processing Record 29 of Set 1 | atuona
# Processing Record 30 of Set 1 | avarua
# Processing Record 31 of Set 1 | hermanus
# Processing Record 32 of Set 1 | bethel
# Processing Record 33 of Set 1 | lazaro cardenas
# Processing Record 34 of Set 1 | hasaki
# Processing Record 35 of Set 1 | jasper
# Processing Record 36 of Set 1 | cape town
# Processing Record 37 of Set 1 | barela
# Processing Record 38 of Set 1 | asau
# Processing Record 39 of Set 1 | chardara
# Processing Record 40 of Set 1 | port lincoln
# Processing Record 41 of Set 1 | mataura
# Processing Record 42 of Set 1 | astipalaia
# City not found. Skipping...
# Processing Record 43 of Set 1 | mar del plata
# Processing Record 44 of Set 1 | codrington
# Processing Record 45 of Set 1 | ancud
# Processing Record 46 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 47 of Set 1 | karkaralinsk
# City not found. Skipping...
# Processing Record 48 of Set 1 | new norfolk
# Processing Record 49 of Set 1 | bredasdorp
# Processing Record 50 of Set 1 | solsvik
# City not found. Skipping...
# Processing Record 1 of Set 2 | acapulco
# Processing Record 2 of Set 2 | punta arenas
# Processing Record 3 of Set 2 | qandala
# Processing Record 4 of Set 2 | vaini
# Processing Record 5 of Set 2 | salamiyah
# Processing Record 6 of Set 2 | kochki
# Processing Record 7 of Set 2 | karamea
# City not found. Skipping...
# Processing Record 8 of Set 2 | longlac
# City not found. Skipping...
# Processing Record 9 of Set 2 | port elizabeth
# Processing Record 10 of Set 2 | hobart
# Processing Record 11 of Set 2 | fairbanks
# Processing Record 12 of Set 2 | cidreira
# Processing Record 13 of Set 2 | olinda
# Processing Record 14 of Set 2 | pevek
# Processing Record 15 of Set 2 | sandane
# Processing Record 16 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 17 of Set 2 | guerrero negro
# Processing Record 18 of Set 2 | upernavik
# Processing Record 19 of Set 2 | imbituba
# Processing Record 20 of Set 2 | odweyne
# Processing Record 21 of Set 2 | albany
# Processing Record 22 of Set 2 | rawannawi
# City not found. Skipping...
# Processing Record 23 of Set 2 | kibre mengist
# Processing Record 24 of Set 2 | salalah
# Processing Record 25 of Set 2 | labuan
# Processing Record 26 of Set 2 | puerto ayora
# Processing Record 27 of Set 2 | price
# Processing Record 28 of Set 2 | khasan
# Processing Record 29 of Set 2 | broome
# Processing Record 30 of Set 2 | remanso
# Processing Record 31 of Set 2 | rancho palos verdes
# Processing Record 32 of Set 2 | jamestown
# Processing Record 33 of Set 2 | kununurra
# Processing Record 34 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 35 of Set 2 | arraial do cabo
# Processing Record 36 of Set 2 | lovington
# Processing Record 37 of Set 2 | khatanga
# Processing Record 38 of Set 2 | santa isabel do rio negro
# Processing Record 39 of Set 2 | severo-kurilsk
# Processing Record 40 of Set 2 | canaries
# Processing Record 41 of Set 2 | chapais
# Processing Record 42 of Set 2 | thompson
# Processing Record 43 of Set 2 | saint-philippe
# Processing Record 44 of Set 2 | kodiak
# Processing Record 45 of Set 2 | oudtshoorn
# Processing Record 46 of Set 2 | ossora
# Processing Record 47 of Set 2 | proletarsk
# Processing Record 48 of Set 2 | laguna
# Processing Record 49 of Set 2 | castro
# Processing Record 50 of Set 2 | borogontsy
# Processing Record 1 of Set 3 | pacific grove
# Processing Record 2 of Set 3 | verkhnyaya inta
# Processing Record 3 of Set 3 | laiagam
# City not found. Skipping...
# Processing Record 4 of Set 3 | sorland
# Processing Record 5 of Set 3 | athabasca
# Processing Record 6 of Set 3 | nikolskoye
# Processing Record 7 of Set 3 | coquimbo
# Processing Record 8 of Set 3 | otradnoye
# Processing Record 9 of Set 3 | barrow
# Processing Record 10 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 11 of Set 3 | sorvag
# City not found. Skipping...
# Processing Record 12 of Set 3 | monte patria
# Processing Record 13 of Set 3 | gat
# Processing Record 14 of Set 3 | avera
# Processing Record 15 of Set 3 | san jeronimo
# Processing Record 16 of Set 3 | victoria
# Processing Record 17 of Set 3 | conakry
# Processing Record 18 of Set 3 | narsaq
# Processing Record 19 of Set 3 | waddan
# Processing Record 20 of Set 3 | vaovai
# City not found. Skipping...
# Processing Record 21 of Set 3 | tasiilaq
# Processing Record 22 of Set 3 | buzmeyin
# Processing Record 23 of Set 3 | paradwip
# City not found. Skipping...
# Processing Record 24 of Set 3 | mocuba
# Processing Record 25 of Set 3 | turbiv
# Processing Record 26 of Set 3 | berdigestyakh
# Processing Record 27 of Set 3 | gimli
# Processing Record 28 of Set 3 | sur
# Processing Record 29 of Set 3 | kalianget
# Processing Record 30 of Set 3 | dingle
# Processing Record 31 of Set 3 | cayenne
# Processing Record 32 of Set 3 | east london
# Processing Record 33 of Set 3 | carnarvon
# Processing Record 34 of Set 3 | hvide sande
# Processing Record 35 of Set 3 | haguenau
# Processing Record 36 of Set 3 | kavieng
# Processing Record 37 of Set 3 | porto de moz
# Processing Record 38 of Set 3 | nianzishan
# Processing Record 39 of Set 3 | qaanaaq
# Processing Record 40 of Set 3 | port alfred
# Processing Record 41 of Set 3 | warkworth
# Processing Record 42 of Set 3 | ewa beach
# Processing Record 43 of Set 3 | irituia
# Processing Record 44 of Set 3 | ruatoria
# City not found. Skipping...
# Processing Record 45 of Set 3 | lebu
# Processing Record 46 of Set 3 | udachnyy
# Processing Record 47 of Set 3 | hilo
# Processing Record 48 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 49 of Set 3 | ende
# Processing Record 50 of Set 3 | port keats
# Processing Record 1 of Set 4 | sawtell
# Processing Record 2 of Set 4 | iqaluit
# Processing Record 3 of Set 4 | popondetta
# Processing Record 4 of Set 4 | tafalla
# Processing Record 5 of Set 4 | tiksi
# Processing Record 6 of Set 4 | butaritari
# Processing Record 7 of Set 4 | prado
# Processing Record 8 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 9 of Set 4 | riberalta
# Processing Record 10 of Set 4 | san cristobal
# Processing Record 11 of Set 4 | sola
# Processing Record 12 of Set 4 | ponta delgada
# Processing Record 13 of Set 4 | tuatapere
# Processing Record 14 of Set 4 | piacabucu
# Processing Record 15 of Set 4 | namibe
# Processing Record 16 of Set 4 | yumen
# Processing Record 17 of Set 4 | laredo
# Processing Record 18 of Set 4 | tangwani
# Processing Record 19 of Set 4 | dikson
# Processing Record 20 of Set 4 | tessalit
# Processing Record 21 of Set 4 | alice springs
# Processing Record 22 of Set 4 | tuktoyaktuk
# Processing Record 23 of Set 4 | raga
# Processing Record 24 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 25 of Set 4 | kamphaeng phet
# Processing Record 26 of Set 4 | riosucio
# Processing Record 27 of Set 4 | cururupu
# Processing Record 28 of Set 4 | kulhudhuffushi
# Processing Record 29 of Set 4 | ubaira
# Processing Record 30 of Set 4 | seoul
# Processing Record 31 of Set 4 | balabac
# Processing Record 32 of Set 4 | okara
# Processing Record 33 of Set 4 | santa rosa
# Processing Record 34 of Set 4 | ahipara
# Processing Record 35 of Set 4 | byron bay
# Processing Record 36 of Set 4 | arawa
# Processing Record 37 of Set 4 | la union
# Processing Record 38 of Set 4 | bambous virieux
# Processing Record 39 of Set 4 | aichach
# Processing Record 40 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 41 of Set 4 | hamilton
# Processing Record 42 of Set 4 | havre-saint-pierre
# Processing Record 43 of Set 4 | brits
# Processing Record 44 of Set 4 | abu samrah
# Processing Record 45 of Set 4 | sungairaya
# Processing Record 46 of Set 4 | babolna
# Processing Record 47 of Set 4 | mannarakkat
# Processing Record 48 of Set 4 | okhotsk
# Processing Record 49 of Set 4 | ribeira grande
# Processing Record 50 of Set 4 | vestmannaeyjar
# Processing Record 1 of Set 5 | gusau
# Processing Record 2 of Set 5 | norman wells
# Processing Record 3 of Set 5 | erzin
# Processing Record 4 of Set 5 | kytmanovo
# Processing Record 5 of Set 5 | katangli
# Processing Record 6 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 7 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 8 of Set 5 | malaryta
# Processing Record 9 of Set 5 | quatre cocos
# Processing Record 10 of Set 5 | mawlamyine
# Processing Record 11 of Set 5 | muzaffargarh
# Processing Record 12 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 13 of Set 5 | nanortalik
# Processing Record 14 of Set 5 | malwan
# City not found. Skipping...
# Processing Record 15 of Set 5 | chuy
# Processing Record 16 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 17 of Set 5 | teya
# Processing Record 18 of Set 5 | fortuna
# Processing Record 19 of Set 5 | prince rupert
# Processing Record 20 of Set 5 | znamensk
# Processing Record 21 of Set 5 | evensk
# Processing Record 22 of Set 5 | geraldton
# Processing Record 23 of Set 5 | muros
# Processing Record 24 of Set 5 | airai
# Processing Record 25 of Set 5 | meulaboh
# Processing Record 26 of Set 5 | waipawa
# Processing Record 27 of Set 5 | alofi
# Processing Record 28 of Set 5 | katsuura
# Processing Record 29 of Set 5 | ekhabi
# Processing Record 30 of Set 5 | kapaa
# Processing Record 31 of Set 5 | bastia
# Processing Record 32 of Set 5 | luang prabang
# Processing Record 33 of Set 5 | dien bien
# City not found. Skipping...
# Processing Record 34 of Set 5 | ushtobe
# Processing Record 35 of Set 5 | ambon
# Processing Record 36 of Set 5 | baghdad
# Processing Record 37 of Set 5 | huarmey
# Processing Record 38 of Set 5 | lagoa
# Processing Record 39 of Set 5 | camacha
# Processing Record 40 of Set 5 | ulcinj
# Processing Record 41 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 42 of Set 5 | sesheke
# Processing Record 43 of Set 5 | port blair
# Processing Record 44 of Set 5 | burnie
# Processing Record 45 of Set 5 | bay roberts
# Processing Record 46 of Set 5 | kichera
# Processing Record 47 of Set 5 | nisia floresta
# Processing Record 48 of Set 5 | saint-augustin
# Processing Record 49 of Set 5 | chokurdakh
# Processing Record 50 of Set 5 | buala
# Processing Record 1 of Set 6 | killybegs
# Processing Record 2 of Set 6 | hithadhoo
# Processing Record 3 of Set 6 | mount gambier
# Processing Record 4 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 5 of Set 6 | iquitos
# Processing Record 6 of Set 6 | naze
# Processing Record 7 of Set 6 | aguimes
# Processing Record 8 of Set 6 | celestun
# Processing Record 9 of Set 6 | georgetown
# Processing Record 10 of Set 6 | khalandritsa
# City not found. Skipping...
# Processing Record 11 of Set 6 | biak
# Processing Record 12 of Set 6 | carai
# Processing Record 13 of Set 6 | manta
# Processing Record 14 of Set 6 | taburi
# City not found. Skipping...
# Processing Record 15 of Set 6 | baoqing
# Processing Record 16 of Set 6 | xining
# Processing Record 17 of Set 6 | corsicana
# Processing Record 18 of Set 6 | luderitz
# Processing Record 19 of Set 6 | cartagena del chaira
# Processing Record 20 of Set 6 | zouxian
# City not found. Skipping...
# Processing Record 21 of Set 6 | estelle
# Processing Record 22 of Set 6 | srednekolymsk
# Processing Record 23 of Set 6 | amuntai
# Processing Record 24 of Set 6 | vila velha
# Processing Record 25 of Set 6 | tsuyama
# Processing Record 26 of Set 6 | ostersund
# Processing Record 27 of Set 6 | surgut
# Processing Record 28 of Set 6 | yichang
# Processing Record 29 of Set 6 | bandarbeyla
# Processing Record 30 of Set 6 | adre
# Processing Record 31 of Set 6 | mount isa
# Processing Record 32 of Set 6 | fergus falls
# Processing Record 33 of Set 6 | balyaga
# Processing Record 34 of Set 6 | lorengau
# Processing Record 35 of Set 6 | tasbuget
# City not found. Skipping...
# Processing Record 36 of Set 6 | qeshm
# Processing Record 37 of Set 6 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 38 of Set 6 | jacareacanga
# Processing Record 39 of Set 6 | olafsvik
# Processing Record 40 of Set 6 | saskylakh
# Processing Record 41 of Set 6 | yulara
# Processing Record 42 of Set 6 | lakselv
# Processing Record 43 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 44 of Set 6 | lakhdenpokhya
# Processing Record 45 of Set 6 | tura
# Processing Record 46 of Set 6 | halifax
# Processing Record 47 of Set 6 | utica
# Processing Record 48 of Set 6 | buraydah
# Processing Record 49 of Set 6 | progreso
# Processing Record 50 of Set 6 | sotouboua
# Processing Record 1 of Set 7 | menongue
# Processing Record 2 of Set 7 | ramos arizpe
# Processing Record 3 of Set 7 | kilindoni
# Processing Record 4 of Set 7 | jaguarao
# Processing Record 5 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 6 of Set 7 | saldanha
# Processing Record 7 of Set 7 | banda aceh
# Processing Record 8 of Set 7 | deputatskiy
# Processing Record 9 of Set 7 | san jose
# Processing Record 10 of Set 7 | isangel
# Processing Record 11 of Set 7 | vanimo
# Processing Record 12 of Set 7 | cherskiy
# Processing Record 13 of Set 7 | san juan
# Processing Record 14 of Set 7 | yartsevo
# Processing Record 15 of Set 7 | nyimba
# Processing Record 16 of Set 7 | nyurba
# Processing Record 17 of Set 7 | salo
# Processing Record 18 of Set 7 | upington
# Processing Record 19 of Set 7 | scarborough
# Processing Record 20 of Set 7 | flinders
# Processing Record 21 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 22 of Set 7 | zlatoust
# Processing Record 23 of Set 7 | bengkulu
# Processing Record 24 of Set 7 | aklavik
# Processing Record 25 of Set 7 | omsukchan
# Processing Record 26 of Set 7 | hofn
# Processing Record 27 of Set 7 | broken hill
# Processing Record 28 of Set 7 | cap malheureux
# Processing Record 29 of Set 7 | inta
# Processing Record 30 of Set 7 | gunjur
# Processing Record 31 of Set 7 | torbay
# Processing Record 32 of Set 7 | puerto escondido
# Processing Record 33 of Set 7 | grand gaube
# Processing Record 34 of Set 7 | yantal
# Processing Record 35 of Set 7 | tuggurt
# City not found. Skipping...
# Processing Record 36 of Set 7 | sinnamary
# Processing Record 37 of Set 7 | kologriv
# Processing Record 38 of Set 7 | severo-yeniseyskiy
# Processing Record 39 of Set 7 | yuli
# Processing Record 40 of Set 7 | garowe
# Processing Record 41 of Set 7 | vagur
# Processing Record 42 of Set 7 | saint-pierre
# Processing Record 43 of Set 7 | del rio
# Processing Record 44 of Set 7 | baruun-urt
# Processing Record 45 of Set 7 | parabel
# Processing Record 46 of Set 7 | eskasem
# City not found. Skipping...
# Processing Record 47 of Set 7 | eyl
# Processing Record 48 of Set 7 | kushiro
# Processing Record 49 of Set 7 | lasa
# Processing Record 50 of Set 7 | sedelnikovo
# City not found. Skipping...
# Processing Record 1 of Set 8 | terrace
# Processing Record 2 of Set 8 | souillac
# Processing Record 3 of Set 8 | umm lajj
# Processing Record 4 of Set 8 | komsomolskiy
# Processing Record 5 of Set 8 | bandarban
# Processing Record 6 of Set 8 | hambantota
# Processing Record 7 of Set 8 | svetlyy
# Processing Record 8 of Set 8 | inverell
# Processing Record 9 of Set 8 | poum
# Processing Record 10 of Set 8 | esperance
# Processing Record 11 of Set 8 | kaitangata
# Processing Record 12 of Set 8 | nyazepetrovsk
# Processing Record 13 of Set 8 | ucluelet
# Processing Record 14 of Set 8 | beloha
# Processing Record 15 of Set 8 | mercedes
# Processing Record 16 of Set 8 | gazli
# Processing Record 17 of Set 8 | livingston
# Processing Record 18 of Set 8 | elk city
# Processing Record 19 of Set 8 | wanning
# Processing Record 20 of Set 8 | roald
# Processing Record 21 of Set 8 | maria aurora
# Processing Record 22 of Set 8 | ankang
# Processing Record 23 of Set 8 | williams lake
# Processing Record 24 of Set 8 | aswan
# Processing Record 25 of Set 8 | tautira
# Processing Record 26 of Set 8 | nyirtass
# Processing Record 27 of Set 8 | nara
# Processing Record 28 of Set 8 | nouadhibou
# Processing Record 29 of Set 8 | sao filipe
# Processing Record 30 of Set 8 | yarada
# Processing Record 31 of Set 8 | tunceli
# Processing Record 32 of Set 8 | saint andrews
# Processing Record 33 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 34 of Set 8 | maymanak
# City not found. Skipping...
# Processing Record 35 of Set 8 | lavrentiya
# Processing Record 36 of Set 8 | lincoln
# Processing Record 37 of Set 8 | severnoye
# Processing Record 38 of Set 8 | santa barbara
# Processing Record 39 of Set 8 | longyearbyen
# Processing Record 40 of Set 8 | hastings
# Processing Record 41 of Set 8 | grasse
# Processing Record 42 of Set 8 | zonguldak
# Processing Record 43 of Set 8 | banjar
# Processing Record 44 of Set 8 | klaksvik
# Processing Record 45 of Set 8 | woodland
# Processing Record 46 of Set 8 | tilichiki
# Processing Record 47 of Set 8 | katherine
# Processing Record 48 of Set 8 | nemuro
# Processing Record 49 of Set 8 | nola
# Processing Record 50 of Set 8 | adrar
# Processing Record 1 of Set 9 | mahajanga
# Processing Record 2 of Set 9 | nha trang
# Processing Record 3 of Set 9 | vista hermosa
# Processing Record 4 of Set 9 | solovetskiy
# City not found. Skipping...
# Processing Record 5 of Set 9 | aasiaat
# Processing Record 6 of Set 9 | dabola
# Processing Record 7 of Set 9 | manga
# Processing Record 8 of Set 9 | voh
# Processing Record 9 of Set 9 | lac du bonnet
# Processing Record 10 of Set 9 | itarema
# Processing Record 11 of Set 9 | korla
# Processing Record 12 of Set 9 | pangnirtung
# Processing Record 13 of Set 9 | banfora
# Processing Record 14 of Set 9 | bowen
# Processing Record 15 of Set 9 | tignere
# Processing Record 16 of Set 9 | dhidhdhoo
# Processing Record 17 of Set 9 | esmeraldas
# Processing Record 18 of Set 9 | biltine
# Processing Record 19 of Set 9 | ponta do sol
# Processing Record 20 of Set 9 | praya
# Processing Record 21 of Set 9 | provideniya
# Processing Record 22 of Set 9 | peniche
# Processing Record 23 of Set 9 | mocambique
# City not found. Skipping...
# Processing Record 24 of Set 9 | manacapuru
# Processing Record 25 of Set 9 | jardim
# Processing Record 26 of Set 9 | mecca
# Processing Record 27 of Set 9 | leningradskiy
# Processing Record 28 of Set 9 | clyde river
# Processing Record 29 of Set 9 | matagami
# Processing Record 30 of Set 9 | sibiti
# Processing Record 31 of Set 9 | pedernales
# Processing Record 32 of Set 9 | soe
# Processing Record 33 of Set 9 | jaruco
# Processing Record 34 of Set 9 | blonduos
# City not found. Skipping...
# Processing Record 35 of Set 9 | tera
# Processing Record 36 of Set 9 | safford
# Processing Record 37 of Set 9 | lucea
# Processing Record 38 of Set 9 | gumdag
# Processing Record 39 of Set 9 | nizhnyaya pavlovka
# City not found. Skipping...
# Processing Record 40 of Set 9 | dudinka
# Processing Record 41 of Set 9 | butte
# Processing Record 42 of Set 9 | ulaangom
# Processing Record 43 of Set 9 | wiarton
# Processing Record 44 of Set 9 | pizarro
# Processing Record 45 of Set 9 | rio grande
# Processing Record 46 of Set 9 | te anau
# Processing Record 47 of Set 9 | mildura
# Processing Record 48 of Set 9 | kabinda
# Processing Record 49 of Set 9 | bara
# Processing Record 50 of Set 9 | uruzgan
# Processing Record 1 of Set 10 | saint anthony
# Processing Record 2 of Set 10 | lulea
# Processing Record 3 of Set 10 | margate
# Processing Record 4 of Set 10 | ipojuca
# Processing Record 5 of Set 10 | algiers
# Processing Record 6 of Set 10 | gull lake
# Processing Record 7 of Set 10 | linhares
# Processing Record 8 of Set 10 | scottsboro
# Processing Record 9 of Set 10 | srinagar
# Processing Record 10 of Set 10 | birao
# Processing Record 11 of Set 10 | zolotinka
# City not found. Skipping...
# Processing Record 12 of Set 10 | labutta
# City not found. Skipping...
# Processing Record 13 of Set 10 | foumban
# Processing Record 14 of Set 10 | murdochville
# Processing Record 15 of Set 10 | sulurpeta
# City not found. Skipping...
# Processing Record 16 of Set 10 | strezhevoy
# Processing Record 17 of Set 10 | thinadhoo
# Processing Record 18 of Set 10 | karasjok
# Processing Record 19 of Set 10 | north bend
# Processing Record 20 of Set 10 | sorong
# Processing Record 21 of Set 10 | taoudenni
# Processing Record 22 of Set 10 | bedesa
# Processing Record 23 of Set 10 | talnakh
# Processing Record 24 of Set 10 | nuuk
# Processing Record 25 of Set 10 | ouango
# Processing Record 26 of Set 10 | ust-nera
# Processing Record 27 of Set 10 | kautokeino
# Processing Record 28 of Set 10 | coihaique
# Processing Record 29 of Set 10 | balkhash
# Processing Record 30 of Set 10 | paamiut
# Processing Record 31 of Set 10 | khandyga
# Processing Record 32 of Set 10 | muscle shoals
# Processing Record 33 of Set 10 | teykovo
# Processing Record 34 of Set 10 | santa isabel do para
# Processing Record 35 of Set 10 | honningsvag
# Processing Record 36 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 37 of Set 10 | porbandar
# Processing Record 38 of Set 10 | lompoc
# Processing Record 39 of Set 10 | mahebourg
# Processing Record 40 of Set 10 | cravo norte
# Processing Record 41 of Set 10 | atikokan
# Processing Record 42 of Set 10 | yar-sale
# Processing Record 43 of Set 10 | padang
# Processing Record 44 of Set 10 | abengourou
# Processing Record 45 of Set 10 | oga
# Processing Record 46 of Set 10 | yining
# Processing Record 47 of Set 10 | greenfield
# Processing Record 48 of Set 10 | andevoranto
# City not found. Skipping...
# Processing Record 49 of Set 10 | sarangani
# Processing Record 50 of Set 10 | egvekinot
# Processing Record 1 of Set 11 | kruisfontein
# Processing Record 2 of Set 11 | constitucion
# Processing Record 3 of Set 11 | sibolga
# Processing Record 4 of Set 11 | shenjiamen
# Processing Record 5 of Set 11 | boyolangu
# Processing Record 6 of Set 11 | ballina
# Processing Record 7 of Set 11 | savinskiy
# Processing Record 8 of Set 11 | muncar
# Processing Record 9 of Set 11 | half moon bay
# Processing Record 10 of Set 11 | quang ngai
# Processing Record 11 of Set 11 | inirida
# Processing Record 12 of Set 11 | tangier
# Processing Record 13 of Set 11 | husavik
# Processing Record 14 of Set 11 | latung
# Processing Record 15 of Set 11 | ambilobe
# Processing Record 16 of Set 11 | ho
# City not found. Skipping...
# Processing Record 17 of Set 11 | nanakuli
# Processing Record 18 of Set 11 | haibowan
# City not found. Skipping...
# Processing Record 19 of Set 11 | bintulu
# Processing Record 20 of Set 11 | kinshasa
# Processing Record 21 of Set 11 | ko samui
# Processing Record 22 of Set 11 | yerbogachen
# Processing Record 23 of Set 11 | tomislavgrad
# Processing Record 24 of Set 11 | floro
# Processing Record 25 of Set 11 | barcelona
# Processing Record 26 of Set 11 | marawi
# Processing Record 27 of Set 11 | dharampuri
# Processing Record 28 of Set 11 | maumere
# Processing Record 29 of Set 11 | skibbereen
# Processing Record 30 of Set 11 | vardo
# Processing Record 31 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 32 of Set 11 | big spring
# Processing Record 33 of Set 11 | suez
# Processing Record 34 of Set 11 | santa marta
# Processing Record 35 of Set 11 | okha
# Processing Record 36 of Set 11 | ayagoz
# Processing Record 37 of Set 11 | harper
# Processing Record 38 of Set 11 | fortuna foothills
# Processing Record 39 of Set 11 | sakaraha
# Processing Record 40 of Set 11 | hailar
# Processing Record 41 of Set 11 | pontes e lacerda
# Processing Record 42 of Set 11 | gobabis
# Processing Record 43 of Set 11 | mattru
# Processing Record 44 of Set 11 | borodino
# Processing Record 45 of Set 11 | kefalos
# Processing Record 46 of Set 11 | kavaratti
# Processing Record 47 of Set 11 | mogadishu
# Processing Record 48 of Set 11 | phalombe
# Processing Record 49 of Set 11 | pisco
# Processing Record 50 of Set 11 | hede
# Processing Record 1 of Set 12 | tempoal
# City not found. Skipping...
# Processing Record 2 of Set 12 | slave lake
# Processing Record 3 of Set 12 | temiscaming
# Processing Record 4 of Set 12 | villanueva
# Processing Record 5 of Set 12 | gainesville
# Processing Record 6 of Set 12 | jawhar
# Processing Record 7 of Set 12 | bontang
# Processing Record 8 of Set 12 | samarai
# Processing Record 9 of Set 12 | dmitrovsk-orlovskiy
# Processing Record 10 of Set 12 | oksfjord
# Processing Record 11 of Set 12 | nosy varika
# Processing Record 12 of Set 12 | mahur
# Processing Record 13 of Set 12 | comodoro rivadavia
# Processing Record 14 of Set 12 | parfenyevo
# Processing Record 15 of Set 12 | kapuskasing
# Processing Record 16 of Set 12 | monkey bay
# Processing Record 17 of Set 12 | todos santos
# Processing Record 18 of Set 12 | barcelos
# Processing Record 19 of Set 12 | seinajoki
# Processing Record 20 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 21 of Set 12 | faya
# Processing Record 22 of Set 12 | vreed en hoop
# City not found. Skipping...
# Processing Record 23 of Set 12 | bagno a ripoli
# Processing Record 24 of Set 12 | montero
# Processing Record 25 of Set 12 | naliya
# Processing Record 26 of Set 12 | kumylzhenskaya
# Processing Record 27 of Set 12 | miri
# Processing Record 28 of Set 12 | marzuq
# Processing Record 29 of Set 12 | nadym
# Processing Record 30 of Set 12 | batagay-alyta
# Processing Record 31 of Set 12 | dunedin
# Processing Record 32 of Set 12 | vengerovo
# Processing Record 33 of Set 12 | gladstone
# Processing Record 34 of Set 12 | sebastian
# Processing Record 35 of Set 12 | lhokseumawe
# Processing Record 36 of Set 12 | valdivia
# Processing Record 37 of Set 12 | tarrafal
# Processing Record 38 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 39 of Set 12 | constantine
# Processing Record 40 of Set 12 | tual
# Processing Record 41 of Set 12 | trudovoye
# Processing Record 42 of Set 12 | czersk
# Processing Record 43 of Set 12 | urucui
# Processing Record 44 of Set 12 | iskateley
# Processing Record 45 of Set 12 | rolim de moura
# City not found. Skipping...
# Processing Record 46 of Set 12 | olds
# Processing Record 47 of Set 12 | pacifica
# Processing Record 48 of Set 12 | lake city
# Processing Record 49 of Set 12 | olovyannaya
# Processing Record 50 of Set 12 | limoges
# Processing Record 1 of Set 13 | gornozavodsk
# Processing Record 2 of Set 13 | yialos
# City not found. Skipping...
# Processing Record 3 of Set 13 | diffa
# Processing Record 4 of Set 13 | semnan
# Processing Record 5 of Set 13 | grande riviere du nord
# Processing Record 6 of Set 13 | destin
# Processing Record 7 of Set 13 | kahului
# Processing Record 8 of Set 13 | labuhan
# Processing Record 9 of Set 13 | road town
# Processing Record 10 of Set 13 | samfya
# Processing Record 11 of Set 13 | yarmouth
# Processing Record 12 of Set 13 | cardston
# Processing Record 13 of Set 13 | valparaiso
# Processing Record 14 of Set 13 | nizwa
# Processing Record 15 of Set 13 | bayanday
# Processing Record 16 of Set 13 | chastoozerye
# City not found. Skipping...
# Processing Record 17 of Set 13 | weligama
# Processing Record 18 of Set 13 | greenwood
# Processing Record 19 of Set 13 | vila franca do campo
# Processing Record 20 of Set 13 | mnogovershinnyy
# Processing Record 21 of Set 13 | santa maria
# Processing Record 22 of Set 13 | merauke
# Processing Record 23 of Set 13 | qaqortoq
# Processing Record 24 of Set 13 | musoma
# Processing Record 25 of Set 13 | mlonggo
# Processing Record 26 of Set 13 | lakhna
# Processing Record 27 of Set 13 | carutapera
# Processing Record 28 of Set 13 | ostrovnoy
# Processing Record 29 of Set 13 | ust-uda
# Processing Record 30 of Set 13 | cabedelo
# Processing Record 31 of Set 13 | belmonte
# Processing Record 32 of Set 13 | bundaberg
# Processing Record 33 of Set 13 | alotau
# City not found. Skipping...
# Processing Record 34 of Set 13 | astoria
# Processing Record 35 of Set 13 | kiunga
# Processing Record 36 of Set 13 | xai-xai
# Processing Record 37 of Set 13 | belyy yar
# Processing Record 38 of Set 13 | bennettsville
# Processing Record 39 of Set 13 | santa rita
# Processing Record 40 of Set 13 | nhulunbuy
# Processing Record 41 of Set 13 | clonmel
# Processing Record 42 of Set 13 | sosnowiec
# Processing Record 43 of Set 13 | pundaguitan
# Processing Record 44 of Set 13 | kawana waters
# City not found. Skipping...
# Processing Record 45 of Set 13 | beringovskiy
# Processing Record 46 of Set 13 | portland
# Processing Record 47 of Set 13 | alugan
# Processing Record 48 of Set 13 | anloga
# Processing Record 49 of Set 13 | galway
# Processing Record 50 of Set 13 | bagdarin
# Processing Record 1 of Set 14 | necochea
# Processing Record 2 of Set 14 | porto velho
# Processing Record 3 of Set 14 | jinchang
# Processing Record 4 of Set 14 | suraabad
# Processing Record 5 of Set 14 | luau
# Processing Record 6 of Set 14 | sitka
# Processing Record 7 of Set 14 | mitu
# Processing Record 8 of Set 14 | cockburn town
# Processing Record 9 of Set 14 | klobuck
# Processing Record 10 of Set 14 | kuching
# Processing Record 11 of Set 14 | baihar
# Processing Record 12 of Set 14 | nantucket
# Processing Record 13 of Set 14 | machinga
# Processing Record 14 of Set 14 | hirna
# Processing Record 15 of Set 14 | gallup
# Processing Record 16 of Set 14 | surdulica
# Processing Record 17 of Set 14 | okato
# Processing Record 18 of Set 14 | bulgan
# Processing Record 19 of Set 14 | ciudad bolivar
# Processing Record 20 of Set 14 | oyama
# Processing Record 21 of Set 14 | mareeba
# Processing Record 22 of Set 14 | cockburn harbour
# City not found. Skipping...
# Processing Record 23 of Set 14 | brigantine
# Processing Record 24 of Set 14 | haines junction
# Processing Record 25 of Set 14 | moosomin
# Processing Record 26 of Set 14 | bonavista
# Processing Record 27 of Set 14 | stavern
# Processing Record 28 of Set 14 | santa cruz
# Processing Record 29 of Set 14 | pasighat
# Processing Record 30 of Set 14 | angangxi
# City not found. Skipping...
# Processing Record 31 of Set 14 | kasongo-lunda
# Processing Record 32 of Set 14 | yaan
# Processing Record 33 of Set 14 | mahadday weyne
# City not found. Skipping...
# Processing Record 34 of Set 14 | istmina
# Processing Record 35 of Set 14 | leh
# Processing Record 36 of Set 14 | yeniseysk
# Processing Record 37 of Set 14 | artyk
# City not found. Skipping...
# Processing Record 38 of Set 14 | paraiso
# Processing Record 39 of Set 14 | sao joao da barra
# Processing Record 40 of Set 14 | gigmoto
# Processing Record 41 of Set 14 | mikhaylovka
# Processing Record 42 of Set 14 | fort nelson
# Processing Record 43 of Set 14 | banjarmasin
# Processing Record 44 of Set 14 | saryozek
# Processing Record 45 of Set 14 | yakeshi
# Processing Record 46 of Set 14 | attawapiskat
# City not found. Skipping...
# Processing Record 47 of Set 14 | karaul
# City not found. Skipping...
# Processing Record 48 of Set 14 | puntarenas
# Processing Record 49 of Set 14 | fare
# Processing Record 50 of Set 14 | agirish
# Processing Record 1 of Set 15 | smithers
# Processing Record 2 of Set 15 | hit
# Processing Record 3 of Set 15 | hami
# Processing Record 4 of Set 15 | champerico
# Processing Record 5 of Set 15 | cranbrook
# Processing Record 6 of Set 15 | eureka
# Processing Record 7 of Set 15 | mackay
# Processing Record 8 of Set 15 | magnitka
# Processing Record 9 of Set 15 | basoko
# Processing Record 10 of Set 15 | kirakira
# Processing Record 11 of Set 15 | harindanga
# Processing Record 12 of Set 15 | shiraz
# Processing Record 13 of Set 15 | itacare
# Processing Record 14 of Set 15 | kudahuvadhoo
# Processing Record 15 of Set 15 | zrenjanin
# Processing Record 16 of Set 15 | katol
# Processing Record 17 of Set 15 | vagay
# Processing Record 18 of Set 15 | rakiv lis
# Processing Record 19 of Set 15 | westerville
# Processing Record 20 of Set 15 | naron
# Processing Record 21 of Set 15 | mandan
# Processing Record 22 of Set 15 | galgani
# City not found. Skipping...
# Processing Record 23 of Set 15 | general roca
# Processing Record 24 of Set 15 | the valley
# Processing Record 25 of Set 15 | savannah bight
# Processing Record 26 of Set 15 | serowe
# Processing Record 27 of Set 15 | kadykchan
# City not found. Skipping...
# Processing Record 28 of Set 15 | tommot
# Processing Record 29 of Set 15 | poso
# Processing Record 30 of Set 15 | port hawkesbury
# Processing Record 31 of Set 15 | ust-kut
# Processing Record 32 of Set 15 | the pas
# Processing Record 33 of Set 15 | sungaipenuh
# Processing Record 34 of Set 15 | leirvik
# Processing Record 35 of Set 15 | aflu
# City not found. Skipping...
# Processing Record 36 of Set 15 | balkanabat
# Processing Record 37 of Set 15 | yeppoon
# Processing Record 38 of Set 15 | westport
# Processing Record 39 of Set 15 | penzance
# Processing Record 40 of Set 15 | bereda
# Processing Record 41 of Set 15 | qasigiannguit
# Processing Record 42 of Set 15 | legionowo
# Processing Record 43 of Set 15 | makarov
# Processing Record 44 of Set 15 | chapeco
# Processing Record 45 of Set 15 | vallenar
# Processing Record 46 of Set 15 | domodossola
# Processing Record 47 of Set 15 | aykhal
# Processing Record 48 of Set 15 | dong hoi
# Processing Record 49 of Set 15 | whitehorse
# Processing Record 50 of Set 15 | nador
# Processing Record 1 of Set 16 | moree
# Processing Record 2 of Set 16 | nakapiripirit
# Processing Record 3 of Set 16 | miquelon
# Processing Record 4 of Set 16 | warrnambool
# Processing Record 5 of Set 16 | terney
# Processing Record 6 of Set 16 | uvat
# Processing Record 7 of Set 16 | cherkessk
# Processing Record 8 of Set 16 | chegdomyn
# Processing Record 9 of Set 16 | lyuban
# Processing Record 10 of Set 16 | monchegorsk
# Processing Record 11 of Set 16 | brandon
# Processing Record 12 of Set 16 | garden city
# Processing Record 13 of Set 16 | gushikawa
# Processing Record 14 of Set 16 | la ronge
# Processing Record 15 of Set 16 | andros
# Processing Record 16 of Set 16 | boralday
# Processing Record 17 of Set 16 | mokhsogollokh
# Processing Record 18 of Set 16 | homer
# Processing Record 19 of Set 16 | deniliquin
# Processing Record 20 of Set 16 | sambava
# Processing Record 21 of Set 16 | caravelas
# Processing Record 22 of Set 16 | hovd
# Processing Record 23 of Set 16 | sigerfjord
# City not found. Skipping...
# Processing Record 24 of Set 16 | puerto penasco
# Processing Record 25 of Set 16 | sisimiut
# Processing Record 26 of Set 16 | gairo
# Processing Record 27 of Set 16 | acuna
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 702

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng Country  Max Temp  Humidity  Cloudiness  \
# 0     Batsfjord  70.6345   29.7185      NO     32.07        87          99
# 1          Nome  64.5011 -165.4064      US     26.67        74          75
# 2     Flin Flon  54.7682 -101.8650      CA     44.44        65          75
# 3         Bluff -46.6000  168.3333      NZ     54.72        86          76
# 4       Ushuaia -54.8000  -68.3000      AR     35.26        87          40
# 5           Vao -22.6667  167.4833      NC     72.45        69          42
# 6        Faanui -16.4833 -151.7500      PF     75.13        89          98
# 7     Manzhouli  49.6000  117.4333      CN     30.56        81           5
# 8     Barabinsk  55.3571   78.3570      RU     42.80        82         100
# 9  Umm Kaddadah  13.6017   26.6876      SD     82.65        21          97
#
#    Wind Speed Current Description
# 0       21.32          light snow
# 1       13.80       broken clouds
# 2       14.97       broken clouds
# 3        7.34       broken clouds
# 4       20.71          light snow
# 5       13.40    scattered clouds
# 6        7.94       moderate rain
# 7       18.52           clear sky
# 8        8.39          light rain
# 9       16.93     overcast clouds

# %%
#reorder columns
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df["Lat"] = city_data_df["Lat"].map("{:,.2f}".format)
city_data_df["Lng"] = city_data_df["Lng"].map("{:,.2f}".format)
city_data_df.head()
# Out:
#         City Country     Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0  Batsfjord      NO   70.63    29.72     32.07        87          99
# 1       Nome      US   64.50  -165.41     26.67        74          75
# 2  Flin Flon      CA   54.77  -101.86     44.44        65          75
# 3      Bluff      NZ  -46.60   168.33     54.72        86          76
# 4    Ushuaia      AR  -54.80   -68.30     35.26        87          40
#
#    Wind Speed Current Description
# 0       21.32          light snow
# 1       13.80       broken clouds
# 2       14.97       broken clouds
# 3        7.34       broken clouds
# 4       20.71          light snow

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
